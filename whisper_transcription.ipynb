# %% [markdown]
# # 🎙️ Speech-to-Text with OpenAI Whisper
# Transcribe speech from a video or audio file.

# %%
# Install Whisper (run once)
# !pip install openai-whisper

# %%
# If you have conda (which you do — Anaconda path detected)
# !conda install -c conda-forge ffmpeg -y
# Out:
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
import whisper

# Load model — choose: 'tiny', 'base', 'small', 'medium', 'large'
# Larger = more accurate but slower
model = whisper.load_model('large')
print('Model loaded!')
# Out:
# 100%|█████████████████████████████████████| 2.88G/2.88G [02:02<00:00, 25.2MiB/s]
# Model loaded!

# %%
# Set the path to your video or audio file
VIDEO_PATH = r'/Users/rayan/Downloads/WhatsApp Video 2026-03-14 at 4.59.25 AM.mp4'  # <-- change this

# Transcribe
result = model.transcribe(VIDEO_PATH)

# Print the full transcript
print(result['text'])
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ...

# %%
# Save transcript to a text file
with open('transcript.txt', 'w') as f:
    f.write(result['text'])

print('Saved to transcript.txt')
# Out:
# Saved to transcript.txt

# %%
# BONUS: Print transcript with timestamps (segment by segment)
for segment in result['segments']:
    start = segment['start']
    end = segment['end']
    text = segment['text']
    print(f'[{start:.1f}s --> {end:.1f}s]  {text}')
# Out:
# [0.0s --> 1.4s]   All right, let's jump right in.
# [1.7s --> 4.2s]   We're going to talk about a totally new kind of AI today.
# [4.6s --> 8.2s]   And this one, it's not just trying to figure out if a news story is true or false.
# [8.5s --> 10.5s]   It's trying to do something way more complicated.
# [11.0s --> 14.9s]   It's trying to figure out if we, as humans, are actually going to trust it.
# [15.6s --> 17.0s]   I mean, you know that feeling, right?
# [17.3s --> 20.9s]   You're just scrolling through your feed, you see a news story, a headline, and a picture,
# [21.2s --> 25.2s]   and something in your gut just goes, hang on a sec, that just doesn't feel right.
# [25.5s --> 28.3s]   Yeah, that feeling, that's exactly what we're diving into today.
# [28.3s --> 33.1s]   See, for the longest time, the big goal for AI in the news world was pretty simple, right?
# [33.4s --> 34.8s]   It was basically just a referee.
# [35.2s --> 36.1s]   Is this story true?
# ...
